# %%
import tensorflow as tf

# %%
s = tf.InteractiveSession()

# %%
v1 = tf.Variable(3, name='input_variable1')
c1 = tf.constant(45, name='input_constant1')

# %%
v1.initializer.run()

# %%
result = tf.subtract(c1, v1)

# %%
print(result.eval())
# Out:
# 42

# %%
s.close()
